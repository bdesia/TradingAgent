# %%
from fft_analyzer import StockFFTAnalyzer

# %%
analyzer = StockFFTAnalyzer(ticker='SATL')
analyzer.analyze(top_n=5)
# Out:
# Loaded CSV data (first 5 rows):
#          Date  Close  High    Low  Open   Volume
# 0  2024-12-26   3.89  3.92  3.242  3.36  1531500
# 1  2024-12-27   3.68  4.09  3.410  3.79  1366700
# 2  2024-12-30   3.41  3.88  3.340  3.75   750700
# 3  2024-12-31   2.85  3.37  2.800  3.35   705300
# 4  2025-01-02   3.05  3.26  3.020  3.09   494500
# Columns: ['Date', 'Close', 'High', 'Low', 'Open', 'Volume']
# Loaded 173 valid data points for SATL.
# Applying FFT to SATL prices...
# Finding peaks and troughs...
# Calculating average days between peaks and troughs...
# Average days between peaks: 64.7
# Average days between troughs: 50.0
# Plotting results...
# Dominant cycles (period in days, amplitude):
# Period: 173.0 days, Amplitude: 0.15
# Period: 34.6 days, Amplitude: 0.11
# Period: 28.8 days, Amplitude: 0.10
# Period: 21.6 days, Amplitude: 0.08
